# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhirajharsulkar24/dhiraj_24/blob/master/Covid_19_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STEP 1- ASKING EFFECTIVE QUESTIONS
#
#
# # Q. 1) Show the number of Confirmed, Deaths and Recovered cases in each Region.
# #Q. 2) Remove all the records where the Confirmed Cases is Less Than 10.
# #Q. 3) In which Region, maximum number of Confirmed cases were recorded ?
# #Q. 4) In which Region, minimum number of Deaths cases were recorded ?
# #Q. 5) How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?
# #Q. 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.
# #Q. 6-B ) Sort the entire data wrt No. of Recovered cases in descending order.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # STEP 2
# #Preparing and Prcessing the Dataset For Analysis

# %%
data1=pd.read_csv('covid_19_data.csv')
df=pd.read_csv('covid_19_data.csv')

# %%
del df['State']
df
# Out:
#           Date          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020     Afghanistan       1939      60        252
# 1    4/29/2020         Albania        766      30        455
# 2    4/29/2020         Algeria       3848     444       1702
# 3    4/29/2020         Andorra        743      42        423
# 4    4/29/2020          Angola         27       2          7
# ..         ...             ...        ...     ...        ...
# 316  4/29/2020              US        545       7          0
# 317  4/29/2020  Mainland China         76       3         73
# 318  4/29/2020          Canada         11       0          0
# 319  4/29/2020  Mainland China        185       2        181
# 320  4/29/2020  Mainland China       1268       1       1263
#
# [304 rows x 5 columns]

# %%
df.shape
# Out:
# (304, 5)

# %%
df.isnull().sum()
# Out:
# Date         0
# Region       0
# Confirmed    0
# Deaths       0
# Recovered    0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# Interpretation from above State Column has maxminum number of missing values so we need to perform some Preprocessing

# %% [markdown]
# # STEP 3- ANALYZIE THE DATA TO SOLVE THE QUESTIONS

# %% [markdown]
# # 1.Show the number of Confirmed, Deaths and Recovered cases in each Region

# %%
data=df.groupby('Region')['Confirmed','Deaths','Recovered'].sum()
# Out:
# <ipython-input-46-2927355bac0b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data=df.groupby('Region')['Confirmed','Deaths','Recovered'].sum()

# %%
print(data)
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# Venezuela                 331      10        142
# Vietnam                   270       0        222
# West Bank and Gaza        344       2         71
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [180 rows x 3 columns]

# %% [markdown]
# # 2.Remove all the Records where Confirmed Cases are Less than 10

# %%
df=data1[~(data1['Confirmed']<10)]
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# # 3.In Which Region their maximum number of Confimred cases were recorded

# %%
df.groupby('Region').max('Confirmed').sort_values(by='Confirmed',ascending=False)
# Out:
#             Confirmed  Deaths  Recovered
# Region
# US             299691   23477          0
# Spain          236899   24275     132929
# Italy          203591   27682      71252
# UK             165221   26097        386
# France         165093   24087      48228
# ...               ...     ...        ...
# Seychelles         11       0          6
# Burundi            11       1          4
# Suriname           10       1          8
# Gambia             10       1          8
# Holy See           10       0          2
#
# [180 rows x 3 columns]

# %% [markdown]
# # 4.In which Region maximum number of Deaths cases were recorded

# %%
df.groupby('Region').max('Deaths').sort_values(by='Deaths',ascending=False).head(5)
# Out:
#         Confirmed  Deaths  Recovered
# Region
# Italy      203591   27682      71252
# UK         165221   26097        386
# Spain      236899   24275     132929
# France     165093   24087      48228
# US         299691   23477          0

# %% [markdown]
# # 5.How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020

# %%
df[df['Region']=='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# # 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
df.sort_values(by='Confirmed',ascending=True).head(25)
# Out:
#           Date                        State                            Region  \
# 156  4/29/2020                          NaN                          Suriname
# 70   4/29/2020                          NaN                          Holy See
# 59   4/29/2020                          NaN                            Gambia
# 318  4/29/2020                        Yukon                            Canada
# 217  4/29/2020                    Greenland                           Denmark
# 256  4/29/2020                   Montserrat                                UK
# 144  4/29/2020                          NaN                        Seychelles
# 27   4/29/2020                          NaN                           Burundi
# 306  4/29/2020     Turks and Caicos Islands                                UK
# 118  4/29/2020                          NaN                         Nicaragua
# 215  4/29/2020               Grand Princess                            Canada
# ...

# %% [markdown]
# # 6-B) Sort the entire data wrt No. of Confirmed cases in decending order.

# %%
df.sort_values(by='Confirmed',ascending=False).head(25)
# Out:
#           Date          State          Region  Confirmed  Deaths  Recovered
# 265  4/29/2020       New York              US     299691   23477          0
# 153  4/29/2020            NaN           Spain     236899   24275     132929
# 80   4/29/2020            NaN           Italy     203591   27682      71252
# 168  4/29/2020            NaN              UK     165221   26097          0
# 57   4/29/2020            NaN          France     165093   24087      48228
# 61   4/29/2020            NaN         Germany     161539    6467     120400
# 167  4/29/2020            NaN          Turkey     117589    3081      44040
# 262  4/29/2020     New Jersey              US     116365    6771          0
# 134  4/29/2020            NaN          Russia      99399     972      10286
# 76   4/29/2020            NaN            Iran      93657    5957      73791
# 22   4/29/2020            NaN          Brazil      79685    5513      34132
# ...
